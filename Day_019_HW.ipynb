# %% [markdown]
# ## 作業
# ### 請使用 application_train.csv, 根據不同的 HOUSETYPE_MODE 對 AMT_CREDIT 繪製 Histogram

# %% [markdown]
# # [作業目標]
# - 試著調整資料, 並利用提供的程式繪製分布圖

# %% [markdown]
# # [作業重點]
# - 如何將列出相異的 HOUSETYPE_MODE 類別 (In[3])
# - 如何依照不同的 HOUSETYPE_MODE 類別指定資料, 並繪製長條圖(.hist())? (In[3])

# %%
# 載入需要的套件
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # 另一個繪圖-樣式套件

# 忽略警告訊息
# %matplotlib inline
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# 設定 data_path
dir_data = './data/'

# %%
# 讀取檔案
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
app_train.head()

unique_house_type = app_train['HOUSETYPE_MODE'].value_counts()
print(unique_house_type)
#len(unique_house_type)
# Out:
# Path of read in data: ./data/application_train.csv
# block of flats      150503
# specific housing      1499
# terraced house        1212
# Name: HOUSETYPE_MODE, dtype: int64

# %%
# 使用不同的 HOUSETYPE_MODE 類別繪製圖形, 並使用 subplot 排版
"""
Your Code Here
"""
grouped0=app_train.groupby('HOUSETYPE_MODE').get_group('block of flats')
grouped1=app_train.groupby('HOUSETYPE_MODE').get_group('specific housing')
grouped2=app_train.groupby('HOUSETYPE_MODE').get_group('terraced house')
unique_house_type = app_train['HOUSETYPE_MODE'].value_counts()
print(len(app_train['HOUSETYPE_MODE']))
nrows = len(unique_house_type)
ncols = nrows // 2

plt.figure(figsize=(10,30))
for i in range(len(unique_house_type)):
    plt.subplot(nrows, ncols, i+1)
    """
    Your Code Here
    """ 
    if i == 0:
        grouped0.loc[0:307511,'AMT_INCOME_TOTAL'].hist()
    elif i == 1:
        grouped1.loc[0:307511,'AMT_INCOME_TOTAL'].hist()
    else :
        grouped2.loc[0:307511,'AMT_INCOME_TOTAL'].hist()
    plt.title(str(unique_house_type[i]))
plt.show()    
print(grouped2.loc[0:2000,'AMT_INCOME_TOTAL'])
# Out:
# 307511
# 207     135000.0
# 606      90000.0
# 995     112500.0
# 1155     76500.0
# 1163    315000.0
# 1270    236799.0
# 1896    157500.0
# Name: AMT_INCOME_TOTAL, dtype: float64
